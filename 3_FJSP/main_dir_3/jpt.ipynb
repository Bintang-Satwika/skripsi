# %%
from env_1 import FJSPEnv
import numpy as np
import random
from tqdm import tqdm

import json
import os
import numpy as np
import random

from RULED_BASED import MASKING_action,  FCFS_action, RANDOM_action, HITL_action
# Model directory
# Get the current directory

if __name__ == "__main__":
    env = FJSPEnv(window_size=3, num_agents=3, max_steps=1000)
    rewards = {}
    makespan = {}
    for episode in range(1, 1+1):
        print("\nepisode:", episode)
        state, info = env.reset(seed=1000+episode)
        reward_satu_episode = 0
        done = False
        truncated = False
        #print("\nEpisode:", episode)
        #print("Initial state:", state)
        while not done and not truncated:
            if len(env.conveyor.product_completed)>= env.n_jobs:
                print("All jobs are completed.")
                break

            actions, masking=HITL_action(state, env)
            #actions=FCFS_action(state, env)
            #print("actions:", actions)


            if None in actions:
                print("FAILED ACTION: ", actions)
                break


            next_state, reward, done, truncated, info = env.step(actions)
            env.render()
            reward = np.mean(reward)
            reward_satu_episode += reward
            
            if env.FAILED_ACTION:
                print("episode:", episode)
                print("state:\n", state)
                print("actions:", actions)
                print("next_state:\n", next_state)
                #print(env.observation_all)
                #print("info:", info)
                print("FAILED ENV")
                break

            state = next_state
            #print("next_state:", next_state)

        # if  None in actions:
        #     break

        rewards[episode] = reward_satu_episode
        makespan[episode] = env.step_count
        
        print("Episode complete. Total Reward:", reward_satu_episode, "jumlah step:", env.step_count, "total product completed:", len(env.conveyor.product_completed))
        order = {'A': 0, 'B': 1, 'C': 2}


    env.close()
    print("rewards:", rewards)
    print("makespan:", makespan)

    # file_path= os.path.join(CURRENT_DIR, "Testing_cumulative_rewards_H_2.json")
    # with open(file_path, "w") as f:
    #     json.dump(rewards, f, indent=4)
    # file_path= os.path.join(CURRENT_DIR, "Testing_makespan_H_2.json")
    # with open(file_path, "w") as f:
    #     json.dump(makespan, f, indent=4)

    # file_path= os.path.join(CURRENT_DIR, "Testing_cumulative_rewards_F_zzz.json")
    # with open(file_path, "w") as f:
    #     json.dump(rewards, f, indent=4)
    # file_path= os.path.join(CURRENT_DIR, "Testing_makespan_F_zzz.json")
    # with open(file_path, "w") as f:
    #     json.dump(makespan, f, indent=4)

        #print("product sorted: ",sorted_jobs)
    print("selesai")
# Out:
# episode: 1
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: C-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None 'C-1']
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> C-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None 'C-1' None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> C-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  ['C-1' None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> C-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> C-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None 'C-1']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: B-1 <-> --- <-> --- <-> --- <-> --- <-> C-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None 'B-1']
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None 'C-1' None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> B-1 <-> --- <-> --- <-> --- <-> --- <-> C-1 <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None 'B-1' None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  ['C-1' None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> B-1 <-> --- <-> --- <-> --- <-> --- <-> C-1 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  ['B-1' None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> B-1 <-> --- <-> --- <-> --- <-> --- <-> C-1 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None 'C-1']
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> B-1 <-> --- <-> --- <-> --- <-> --- <-> C-1 <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None 'B-1']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None 'C-1' None]
# workbench:  {}
# Conveyor: B-2 <-> --- <-> --- <-> --- <-> --- <-> B-1 <-> --- <-> --- <-> --- <-> --- <-> C-1 <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None None 'B-2']
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None 'B-1' None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  ['C-1' None None]
# workbench:  {}
# Conveyor: --- <-> B-2 <-> --- <-> --- <-> --- <-> --- <-> B-1 <-> --- <-> --- <-> --- <-> --- <-> C-1
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  [None 'B-2' None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  ['B-1' None None]
# workbench:  {}
# Status Agent 3 at position 11: 1
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> B-2 <-> --- <-> --- <-> --- <-> --- <-> B-1 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 0
# window product:  ['B-2' None None]
# workbench:  {}
# Status Agent 2 at position 7: 1
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'C-1': [1, 3]}
# Conveyor: --- <-> --- <-> --- <-> B-2 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 1
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'C-1': [1, 3]}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'C-1': [1, 3]}
# Conveyor: A-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 2
# window product:  [None None 'A-1']
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'C-1': [1, 3]}
# Conveyor: --- <-> A-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 2
# window product:  [None 'A-1' None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'C-1': [1, 3]}
# Conveyor: --- <-> --- <-> A-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 2
# window product:  ['A-1' None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'C-1': [3]}
# Conveyor: --- <-> --- <-> --- <-> A-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: []
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> A-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'A-1']
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: C-2 <-> --- <-> --- <-> --- <-> --- <-> A-1 <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1']
# Status Agent 1 at position 3: 2
# window product:  [None None 'C-2']
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None 'A-1' None]
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> C-2 <-> --- <-> --- <-> --- <-> --- <-> A-1 <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1']
# Status Agent 1 at position 3: 2
# window product:  [None 'C-2' None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  ['A-1' None None]
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> C-2 <-> --- <-> --- <-> --- <-> --- <-> A-1 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1']
# Status Agent 1 at position 3: 2
# window product:  ['C-2' None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-1': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> C-2 <-> --- <-> --- <-> --- <-> --- <-> A-1 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-1': [3]}
# Status Agent 3 at position 11: 0
# window product:  [None None 'A-1']
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> C-2 <-> --- <-> --- <-> --- <-> --- <-> A-1 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 0
# window product:  [None None 'C-2']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None 'A-1' None]
# workbench:  {}
# Conveyor: A-2 <-> --- <-> --- <-> --- <-> --- <-> C-2 <-> --- <-> --- <-> --- <-> --- <-> A-1 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None None 'A-2']
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 0
# window product:  [None 'C-2' None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  ['A-1' None None]
# workbench:  {}
# Conveyor: --- <-> A-2 <-> --- <-> --- <-> --- <-> --- <-> C-2 <-> --- <-> --- <-> --- <-> --- <-> A-1
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-2' None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 0
# window product:  ['C-2' None None]
# workbench:  {}
# Status Agent 3 at position 11: 1
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> A-2 <-> --- <-> --- <-> --- <-> --- <-> C-2 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  ['A-2' None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'A-1': [1, 2]}
# Conveyor: --- <-> --- <-> --- <-> A-2 <-> --- <-> --- <-> --- <-> --- <-> C-2 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None None 'C-2']
# workbench:  {'A-1': [1, 2]}
# Conveyor: --- <-> --- <-> --- <-> --- <-> A-2 <-> --- <-> --- <-> --- <-> --- <-> C-2 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 0
# window product:  [None None 'A-2']
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None 'C-2' None]
# workbench:  {'A-1': [1, 2]}
# Conveyor: B-3 <-> --- <-> --- <-> --- <-> --- <-> A-2 <-> --- <-> --- <-> --- <-> --- <-> C-2 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None None 'B-3']
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 0
# window product:  [None 'A-2' None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  ['C-2' None None]
# workbench:  {'A-1': [1, 2]}
# Conveyor: --- <-> B-3 <-> --- <-> --- <-> --- <-> --- <-> A-2 <-> --- <-> --- <-> --- <-> --- <-> C-2
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None 'B-3' None]
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 0
# window product:  ['A-2' None None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'A-1': [1, 2]}
# Conveyor: C-2 <-> --- <-> B-3 <-> --- <-> --- <-> --- <-> --- <-> A-2 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  ['B-3' None 'C-2']
# workbench:  {'B-2': [2, 3]}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 3
# window product:  [None None None]
# workbench:  {'A-1': [2]}
# Conveyor: --- <-> C-2 <-> --- <-> B-3 <-> --- <-> --- <-> --- <-> --- <-> A-2 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 3
# window product:  [None 'C-2' None]
# workbench:  {'B-2': [3]}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None 'A-2']
# workbench:  {}
# Conveyor: A-1 <-> --- <-> C-2 <-> --- <-> B-3 <-> --- <-> --- <-> --- <-> --- <-> A-2 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 0
# window product:  ['C-2' None 'A-1']
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None 'B-3']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None 'A-2' None]
# workbench:  {}
# Conveyor: B-4 <-> A-1 <-> --- <-> C-2 <-> B-2 <-> B-3 <-> --- <-> --- <-> --- <-> --- <-> A-2 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 0
# window product:  [None 'A-1' 'B-4']
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None 'B-3' 'B-2']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  ['A-2' None None]
# workbench:  {}
# Conveyor: --- <-> B-4 <-> A-1 <-> --- <-> C-2 <-> B-2 <-> B-3 <-> --- <-> --- <-> --- <-> --- <-> A-2
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 0
# window product:  ['A-1' 'B-4' None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  ['B-3' 'B-2' 'C-2']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: A-2 <-> --- <-> B-4 <-> A-1 <-> --- <-> C-2 <-> B-2 <-> B-3 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 1
# window product:  ['B-4' None 'A-2']
# workbench:  {}
# Status Agent 2 at position 7: 1
# window product:  ['B-2' 'C-2' None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> A-2 <-> --- <-> B-4 <-> --- <-> --- <-> C-2 <-> B-2 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-2' None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  ['C-2' None None]
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> A-2 <-> --- <-> B-4 <-> --- <-> --- <-> C-2 <-> B-2 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  ['A-2' None None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'B-4']
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None None 'B-2']
# workbench:  {}
# Conveyor: A-3 <-> --- <-> --- <-> A-2 <-> --- <-> B-4 <-> --- <-> --- <-> C-2 <-> B-2 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None None 'A-3']
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None 'B-4' None]
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None 'B-2' 'C-2']
# workbench:  {}
# Conveyor: --- <-> A-3 <-> --- <-> --- <-> A-2 <-> --- <-> B-4 <-> --- <-> --- <-> C-2 <-> B-2 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-3' None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  ['B-4' None 'A-2']
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  ['B-2' 'C-2' None]
# workbench:  {}
# Conveyor: --- <-> --- <-> A-3 <-> --- <-> --- <-> A-2 <-> --- <-> B-4 <-> --- <-> --- <-> C-2 <-> B-2
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  ['A-3' None None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None 'A-2' None]
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 1
# window product:  ['C-2' None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> A-3 <-> --- <-> --- <-> A-2 <-> --- <-> B-4 <-> --- <-> --- <-> C-2
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  ['A-2' None None]
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None 'B-4']
# workbench:  {'B-2': [3]}
# Conveyor: C-2 <-> --- <-> --- <-> --- <-> A-3 <-> --- <-> --- <-> A-2 <-> --- <-> B-4 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None None 'C-2']
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'A-3']
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None 'B-4' None]
# workbench:  {'B-2': [3]}
# Conveyor: A-4 <-> C-2 <-> --- <-> --- <-> --- <-> A-3 <-> --- <-> --- <-> A-2 <-> --- <-> B-4 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None 'C-2' 'A-4']
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None 'A-3' None]
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  ['B-4' None 'A-2']
# workbench:  {'B-2': [3]}
# Conveyor: --- <-> A-4 <-> C-2 <-> --- <-> --- <-> --- <-> A-3 <-> --- <-> --- <-> A-2 <-> --- <-> B-4
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  ['C-2' 'A-4' None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  ['A-3' None None]
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None 'A-2' None]
# workbench:  {'B-2': [3]}
# Conveyor: B-4 <-> --- <-> A-4 <-> C-2 <-> --- <-> --- <-> --- <-> A-3 <-> --- <-> --- <-> A-2 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  ['A-4' None 'B-4']
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-3': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  ['A-2' None None]
# workbench:  {'B-2': [3]}
# Conveyor: --- <-> B-4 <-> --- <-> A-4 <-> C-2 <-> --- <-> --- <-> --- <-> A-3 <-> --- <-> --- <-> A-2
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  [None 'B-4' None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'C-2']
# workbench:  {'B-3': [3]}
# Status Agent 3 at position 11: 2
# window product:  [None None 'A-3']
# workbench:  {'B-2': [3]}
# Conveyor: A-2 <-> --- <-> B-4 <-> --- <-> A-4 <-> C-2 <-> --- <-> --- <-> --- <-> A-3 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1']
# Status Agent 1 at position 3: 2
# window product:  ['B-4' None 'A-2']
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 0
# window product:  [None 'C-2' 'A-4']
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None 'A-3' None]
# workbench:  {'B-2': [3]}
# Conveyor: C-3 <-> A-2 <-> --- <-> B-4 <-> --- <-> A-4 <-> C-2 <-> --- <-> --- <-> --- <-> A-3 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-2' 'C-3']
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 0
# window product:  ['C-2' 'A-4' None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  ['A-3' None None]
# workbench:  {'B-2': [3]}
# Conveyor: --- <-> C-3 <-> A-2 <-> --- <-> B-4 <-> --- <-> A-4 <-> C-2 <-> --- <-> --- <-> --- <-> A-3
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3']
# Status Agent 1 at position 3: 2
# window product:  ['A-2' 'C-3' None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 0
# window product:  ['A-4' None 'B-4']
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'B-2': [3]}
# Conveyor: A-3 <-> --- <-> C-3 <-> A-2 <-> --- <-> B-4 <-> --- <-> A-4 <-> C-2 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3']
# Status Agent 1 at position 3: 2
# window product:  ['C-3' None 'A-3']
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 0
# window product:  [None 'B-4' None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None 'C-2']
# workbench:  {}
# Conveyor: --- <-> A-3 <-> --- <-> C-3 <-> A-2 <-> --- <-> B-4 <-> --- <-> A-4 <-> C-2 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-3' None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 0
# window product:  ['B-4' None 'A-2']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None 'C-2' 'A-4']
# workbench:  {}
# Conveyor: --- <-> --- <-> A-3 <-> --- <-> C-3 <-> A-2 <-> --- <-> B-4 <-> --- <-> A-4 <-> C-2 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2']
# Status Agent 1 at position 3: 2
# window product:  ['A-3' None None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 1
# window product:  [None 'A-2' 'C-3']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  ['C-2' 'A-4' None]
# workbench:  {}
# Conveyor: B-5 <-> --- <-> --- <-> A-3 <-> --- <-> C-3 <-> A-2 <-> --- <-> --- <-> --- <-> A-4 <-> C-2
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2']
# Status Agent 1 at position 3: 2
# window product:  [None None 'B-5']
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  ['A-2' 'C-3' None]
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 1
# window product:  ['A-4' None None]
# workbench:  {}
# Conveyor: --- <-> B-5 <-> --- <-> --- <-> A-3 <-> --- <-> C-3 <-> A-2 <-> --- <-> --- <-> --- <-> A-4
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2']
# Status Agent 1 at position 3: 2
# window product:  [None 'B-5' None]
# workbench:  {'A-1': [2]}
# Status Agent 2 at position 7: 2
# window product:  ['C-3' None 'A-3']
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'C-2': [1, 3]}
# Conveyor: A-4 <-> --- <-> B-5 <-> --- <-> --- <-> A-3 <-> --- <-> C-3 <-> A-2 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2']
# Status Agent 1 at position 3: 0
# window product:  ['B-5' None 'A-4']
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None 'A-3' None]
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None 'A-2']
# workbench:  {'C-2': [1, 3]}
# Conveyor: --- <-> A-4 <-> --- <-> B-5 <-> --- <-> --- <-> A-3 <-> --- <-> C-3 <-> A-2 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1']
# Status Agent 1 at position 3: 0
# window product:  [None 'A-4' None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  ['A-3' None None]
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None 'A-2' 'C-3']
# workbench:  {'C-2': [1, 3]}
# Conveyor: --- <-> --- <-> A-4 <-> --- <-> B-5 <-> --- <-> --- <-> A-3 <-> --- <-> C-3 <-> A-2 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1']
# Status Agent 1 at position 3: 0
# window product:  ['A-4' None None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None None 'B-5']
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  ['A-2' 'C-3' None]
# workbench:  {'C-2': [1, 3]}
# Conveyor: A-5 <-> --- <-> --- <-> A-4 <-> --- <-> B-5 <-> --- <-> --- <-> A-3 <-> --- <-> C-3 <-> A-2
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1']
# Status Agent 1 at position 3: 1
# window product:  [None None 'A-5']
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None 'B-5' None]
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  ['C-3' None 'A-3']
# workbench:  {'C-2': [1, 3]}
# Conveyor: A-2 <-> A-5 <-> --- <-> --- <-> --- <-> --- <-> B-5 <-> --- <-> --- <-> A-3 <-> --- <-> C-3
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-5' 'A-2']
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 2
# window product:  ['B-5' None None]
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None 'A-3' None]
# workbench:  {'C-2': [3]}
# Conveyor: C-3 <-> A-2 <-> A-5 <-> --- <-> --- <-> --- <-> --- <-> B-5 <-> --- <-> --- <-> A-3 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1']
# Status Agent 1 at position 3: 2
# window product:  ['A-5' 'A-2' 'C-3']
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  ['A-3' None None]
# workbench:  {}
# Conveyor: --- <-> C-3 <-> A-2 <-> A-5 <-> --- <-> --- <-> --- <-> --- <-> B-5 <-> --- <-> --- <-> A-3
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2']
# Status Agent 1 at position 3: 2
# window product:  ['A-2' 'C-3' None]
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None None 'B-5']
# workbench:  {}
# Conveyor: A-3 <-> --- <-> C-3 <-> A-2 <-> A-5 <-> --- <-> --- <-> --- <-> --- <-> B-5 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2']
# Status Agent 1 at position 3: 2
# window product:  ['C-3' None 'A-3']
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'A-5']
# workbench:  {'B-4': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None 'B-5' None]
# workbench:  {}
# Conveyor: B-6 <-> A-3 <-> --- <-> C-3 <-> A-2 <-> A-5 <-> --- <-> --- <-> --- <-> --- <-> B-5 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-3' 'B-6']
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 2
# window product:  [None 'A-5' 'A-2']
# workbench:  {'B-4': [3]}
# Status Agent 3 at position 11: 0
# window product:  ['B-5' None None]
# workbench:  {}
# Conveyor: --- <-> B-6 <-> A-3 <-> --- <-> C-3 <-> A-2 <-> A-5 <-> --- <-> --- <-> --- <-> --- <-> B-5
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2']
# Status Agent 1 at position 3: 2
# window product:  ['A-3' 'B-6' None]
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 0
# window product:  ['A-5' 'A-2' 'C-3']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: B-5 <-> --- <-> B-6 <-> A-3 <-> --- <-> C-3 <-> A-2 <-> A-5 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4']
# Status Agent 1 at position 3: 2
# window product:  ['B-6' None 'B-5']
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 0
# window product:  ['A-2' 'C-3' None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> B-5 <-> --- <-> B-6 <-> A-3 <-> --- <-> C-3 <-> A-2 <-> A-5 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4']
# Status Agent 1 at position 3: 2
# window product:  [None 'B-5' None]
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 0
# window product:  ['C-3' None 'A-3']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None 'A-5']
# workbench:  {}
# Conveyor: --- <-> --- <-> B-5 <-> --- <-> B-6 <-> A-3 <-> --- <-> C-3 <-> A-2 <-> A-5 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4']
# Status Agent 1 at position 3: 2
# window product:  ['B-5' None None]
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 0
# window product:  [None 'A-3' 'B-6']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None 'A-5' 'A-2']
# workbench:  {}
# Conveyor: B-7 <-> --- <-> --- <-> B-5 <-> --- <-> B-6 <-> A-3 <-> --- <-> C-3 <-> A-2 <-> A-5 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4']
# Status Agent 1 at position 3: 2
# window product:  [None None 'B-7']
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 0
# window product:  ['A-3' 'B-6' None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  ['A-5' 'A-2' 'C-3']
# workbench:  {}
# Conveyor: --- <-> B-7 <-> --- <-> --- <-> B-5 <-> --- <-> B-6 <-> A-3 <-> --- <-> C-3 <-> A-2 <-> A-5
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4']
# Status Agent 1 at position 3: 2
# window product:  [None 'B-7' None]
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 0
# window product:  ['B-6' None 'B-5']
# workbench:  {}
# Status Agent 3 at position 11: 1
# window product:  ['A-2' 'C-3' None]
# workbench:  {}
# Conveyor: --- <-> --- <-> B-7 <-> --- <-> --- <-> B-5 <-> --- <-> B-6 <-> A-3 <-> --- <-> C-3 <-> A-2
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4']
# Status Agent 1 at position 3: 2
# window product:  ['B-7' None None]
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 1
# window product:  [None 'B-5' None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  ['C-3' None 'A-3']
# workbench:  {'A-5': [1, 2]}
# Conveyor: A-2 <-> --- <-> --- <-> B-7 <-> --- <-> --- <-> B-5 <-> --- <-> --- <-> A-3 <-> --- <-> C-3
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4']
# Status Agent 1 at position 3: 2
# window product:  [None None 'A-2']
# workbench:  {'A-4': [1, 2]}
# Status Agent 2 at position 7: 2
# window product:  ['B-5' None None]
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None 'A-3' None]
# workbench:  {'A-5': [1, 2]}
# Conveyor: C-3 <-> A-2 <-> --- <-> --- <-> B-7 <-> --- <-> --- <-> B-5 <-> --- <-> --- <-> A-3 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-2' 'C-3']
# workbench:  {'A-4': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'B-7']
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  ['A-3' None None]
# workbench:  {'A-5': [1, 2]}
# Conveyor: C-4 <-> C-3 <-> A-2 <-> --- <-> --- <-> B-7 <-> --- <-> --- <-> B-5 <-> --- <-> --- <-> A-3
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4']
# Status Agent 1 at position 3: 0
# window product:  ['A-2' 'C-3' 'C-4']
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None 'B-7' None]
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None 'B-5']
# workbench:  {'A-5': [1, 2]}
# Conveyor: A-3 <-> C-4 <-> C-3 <-> A-2 <-> --- <-> --- <-> B-7 <-> --- <-> --- <-> B-5 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4']
# Status Agent 1 at position 3: 0
# window product:  ['C-3' 'C-4' 'A-3']
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  ['B-7' None None]
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None 'B-5' None]
# workbench:  {'A-5': [1, 2]}
# Conveyor: --- <-> A-3 <-> C-4 <-> C-3 <-> A-2 <-> --- <-> --- <-> B-7 <-> --- <-> --- <-> B-5 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4']
# Status Agent 1 at position 3: 1
# window product:  ['C-4' 'A-3' None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None None 'A-2']
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 3
# window product:  ['B-5' None None]
# workbench:  {'A-5': [2]}
# Conveyor: --- <-> --- <-> A-3 <-> C-4 <-> --- <-> A-2 <-> --- <-> --- <-> B-7 <-> --- <-> --- <-> B-5
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4']
# Status Agent 1 at position 3: 2
# window product:  ['A-3' None None]
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None 'A-2' None]
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 3
# window product:  [None None 'B-7']
# workbench:  {'A-5': [2]}
# Conveyor: B-5 <-> --- <-> --- <-> A-3 <-> C-4 <-> --- <-> A-2 <-> --- <-> --- <-> B-7 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4']
# Status Agent 1 at position 3: 2
# window product:  [None None 'B-5']
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  ['A-2' None 'C-4']
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None 'B-7' None]
# workbench:  {}
# Conveyor: A-5 <-> B-5 <-> --- <-> --- <-> A-3 <-> C-4 <-> --- <-> A-2 <-> --- <-> --- <-> B-7 <-> ---
# Buffer: ['A-6']
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4']
# Status Agent 1 at position 3: 2
# window product:  [None 'B-5' 'A-5']
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None 'C-4' 'A-3']
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  ['B-7' None None]
# workbench:  {}
# Conveyor: A-6 <-> A-5 <-> B-5 <-> --- <-> --- <-> A-3 <-> C-4 <-> --- <-> A-2 <-> --- <-> --- <-> B-7
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4']
# Status Agent 1 at position 3: 2
# window product:  ['B-5' 'A-5' 'A-6']
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  ['C-4' 'A-3' None]
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None None 'A-2']
# workbench:  {}
# Conveyor: B-7 <-> A-6 <-> A-5 <-> B-5 <-> --- <-> --- <-> A-3 <-> C-4 <-> --- <-> A-2 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4']
# Status Agent 1 at position 3: 2
# window product:  ['A-5' 'A-6' 'B-7']
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  ['A-3' None None]
# workbench:  {'B-6': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None 'A-2' None]
# workbench:  {}
# Conveyor: --- <-> B-7 <-> A-6 <-> A-5 <-> B-5 <-> --- <-> --- <-> A-3 <-> C-4 <-> --- <-> A-2 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4']
# Status Agent 1 at position 3: 2
# window product:  ['A-6' 'B-7' None]
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'B-5']
# workbench:  {'B-6': [3]}
# Status Agent 3 at position 11: 0
# window product:  ['A-2' None 'C-4']
# workbench:  {}
# Conveyor: --- <-> --- <-> B-7 <-> A-6 <-> A-5 <-> B-5 <-> --- <-> --- <-> A-3 <-> C-4 <-> --- <-> A-2
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4']
# Status Agent 1 at position 3: 2
# window product:  ['B-7' None None]
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 0
# window product:  [None 'B-5' 'A-5']
# workbench:  {}
# Status Agent 3 at position 11: 1
# window product:  [None 'C-4' 'A-3']
# workbench:  {}
# Conveyor: A-7 <-> --- <-> --- <-> B-7 <-> A-6 <-> A-5 <-> B-5 <-> --- <-> --- <-> A-3 <-> C-4 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 2
# window product:  [None None 'A-7']
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 0
# window product:  ['B-5' 'A-5' 'A-6']
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  ['C-4' 'A-3' None]
# workbench:  {'A-2': [1, 2]}
# Conveyor: --- <-> A-7 <-> --- <-> --- <-> B-7 <-> A-6 <-> A-5 <-> B-5 <-> --- <-> --- <-> A-3 <-> C-4
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-7' None]
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 1
# window product:  ['A-5' 'A-6' 'B-7']
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  ['A-3' None None]
# workbench:  {'A-2': [1, 2]}
# Conveyor: C-4 <-> --- <-> A-7 <-> --- <-> --- <-> B-7 <-> A-6 <-> A-5 <-> --- <-> --- <-> --- <-> A-3
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 2
# window product:  ['A-7' None 'C-4']
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  ['A-6' 'B-7' None]
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'A-2': [1, 2]}
# Conveyor: A-3 <-> C-4 <-> --- <-> A-7 <-> --- <-> --- <-> B-7 <-> A-6 <-> A-5 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 2
# window product:  [None 'C-4' 'A-3']
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  ['B-7' None None]
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None None 'A-5']
# workbench:  {'A-2': [1, 2]}
# Conveyor: --- <-> A-3 <-> C-4 <-> --- <-> A-7 <-> --- <-> --- <-> B-7 <-> A-6 <-> A-5 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 2
# window product:  ['C-4' 'A-3' None]
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'A-7']
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 2
# window product:  [None 'A-5' 'A-6']
# workbench:  {'A-2': [1, 2]}
# Conveyor: C-5 <-> --- <-> A-3 <-> C-4 <-> --- <-> A-7 <-> --- <-> --- <-> B-7 <-> A-6 <-> A-5 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 2
# window product:  ['A-3' None 'C-5']
# workbench:  {'C-3': [1, 3]}
# Status Agent 2 at position 7: 2
# window product:  [None 'A-7' None]
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 3
# window product:  ['A-5' 'A-6' 'B-7']
# workbench:  {'A-2': [2]}
# Conveyor: --- <-> C-5 <-> --- <-> A-3 <-> C-4 <-> --- <-> A-7 <-> --- <-> --- <-> B-7 <-> A-6 <-> A-5
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 3
# window product:  [None 'C-5' None]
# workbench:  {'C-3': [3]}
# Status Agent 2 at position 7: 2
# window product:  ['A-7' None 'C-4']
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 3
# window product:  ['A-6' 'B-7' None]
# workbench:  {'A-2': [2]}
# Conveyor: A-5 <-> --- <-> C-5 <-> --- <-> A-3 <-> C-4 <-> --- <-> A-7 <-> --- <-> --- <-> B-7 <-> A-6
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 0
# window product:  ['C-5' None 'A-5']
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None 'C-4' 'A-3']
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 3
# window product:  ['B-7' None None]
# workbench:  {'A-2': [2]}
# Conveyor: A-6 <-> A-5 <-> --- <-> C-5 <-> C-3 <-> A-3 <-> C-4 <-> --- <-> A-7 <-> --- <-> --- <-> B-7
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 0
# window product:  [None 'A-5' 'A-6']
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  ['C-4' 'A-3' 'C-3']
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 3
# window product:  [None None 'A-7']
# workbench:  {'A-2': [2]}
# Conveyor: B-7 <-> A-6 <-> A-5 <-> --- <-> C-5 <-> C-3 <-> A-3 <-> C-4 <-> --- <-> A-7 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 0
# window product:  ['A-5' 'A-6' 'B-7']
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  ['A-3' 'C-3' 'C-5']
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None 'A-7' None]
# workbench:  {}
# Conveyor: A-2 <-> B-7 <-> A-6 <-> A-5 <-> --- <-> C-5 <-> C-3 <-> A-3 <-> C-4 <-> --- <-> A-7 <-> ---
# Buffer: ['C-6']
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 1
# window product:  ['A-6' 'B-7' 'A-2']
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  ['C-3' 'C-5' None]
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  ['A-7' None 'C-4']
# workbench:  {}
# Conveyor: C-6 <-> A-2 <-> B-7 <-> A-6 <-> --- <-> --- <-> C-5 <-> C-3 <-> A-3 <-> C-4 <-> --- <-> A-7
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 2
# window product:  ['B-7' 'A-2' 'C-6']
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 2
# window product:  ['C-5' None None]
# workbench:  {'B-5': [2, 3]}
# Status Agent 3 at position 11: 1
# window product:  [None 'C-4' 'A-3']
# workbench:  {}
# Conveyor: --- <-> C-6 <-> A-2 <-> B-7 <-> A-6 <-> --- <-> --- <-> C-5 <-> C-3 <-> A-3 <-> C-4 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 2
# window product:  ['A-2' 'C-6' None]
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'A-6']
# workbench:  {'B-5': [3]}
# Status Agent 3 at position 11: 2
# window product:  ['C-4' 'A-3' 'C-3']
# workbench:  {'A-7': [1, 2]}
# Conveyor: --- <-> --- <-> C-6 <-> A-2 <-> B-7 <-> A-6 <-> --- <-> --- <-> C-5 <-> C-3 <-> A-3 <-> C-4
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6']
# Status Agent 1 at position 3: 2
# window product:  ['C-6' None None]
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 0
# window product:  [None 'A-6' 'B-7']
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  ['A-3' 'C-3' 'C-5']
# workbench:  {'A-7': [1, 2]}
# Conveyor: C-4 <-> --- <-> --- <-> C-6 <-> A-2 <-> B-7 <-> A-6 <-> --- <-> --- <-> C-5 <-> C-3 <-> A-3
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5']
# Status Agent 1 at position 3: 2
# window product:  [None None 'C-4']
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 0
# window product:  ['A-6' 'B-7' 'A-2']
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  ['C-3' 'C-5' None]
# workbench:  {'A-7': [1, 2]}
# Conveyor: A-3 <-> C-4 <-> --- <-> --- <-> C-6 <-> A-2 <-> B-7 <-> A-6 <-> --- <-> --- <-> C-5 <-> C-3
# Buffer: ['C-7']
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5']
# Status Agent 1 at position 3: 2
# window product:  [None 'C-4' 'A-3']
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 0
# window product:  ['B-7' 'A-2' 'C-6']
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  ['C-5' None None]
# workbench:  {'A-7': [1, 2]}
# Conveyor: C-3 <-> A-3 <-> C-4 <-> --- <-> --- <-> C-6 <-> A-2 <-> B-7 <-> A-6 <-> --- <-> --- <-> C-5
# Buffer: ['C-7']
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5']
# Status Agent 1 at position 3: 2
# window product:  ['C-4' 'A-3' 'C-3']
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 1
# window product:  ['A-2' 'C-6' None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None None 'A-6']
# workbench:  {'A-7': [1, 2]}
# Conveyor: C-5 <-> C-3 <-> A-3 <-> C-4 <-> --- <-> --- <-> C-6 <-> A-2 <-> --- <-> A-6 <-> --- <-> ---
# Buffer: ['C-7']
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5']
# Status Agent 1 at position 3: 2
# window product:  ['A-3' 'C-3' 'C-5']
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 2
# window product:  ['C-6' None None]
# workbench:  {'B-7': [2, 3]}
# Status Agent 3 at position 11: 3
# window product:  [None 'A-6' None]
# workbench:  {'A-7': [2]}
# Conveyor: C-7 <-> C-5 <-> C-3 <-> A-3 <-> C-4 <-> --- <-> --- <-> C-6 <-> A-2 <-> --- <-> A-6 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5']
# Status Agent 1 at position 3: 2
# window product:  ['C-3' 'C-5' 'C-7']
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None 'C-4']
# workbench:  {'B-7': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  ['A-6' None 'A-2']
# workbench:  {}
# Conveyor: A-7 <-> C-7 <-> C-5 <-> C-3 <-> A-3 <-> C-4 <-> --- <-> --- <-> C-6 <-> A-2 <-> --- <-> A-6
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5']
# Status Agent 1 at position 3: 2
# window product:  ['C-5' 'C-7' 'A-7']
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None 'C-4' 'A-3']
# workbench:  {'B-7': [2, 3]}
# Status Agent 3 at position 11: 0
# window product:  [None 'A-2' 'C-6']
# workbench:  {}
# Conveyor: A-6 <-> A-7 <-> C-7 <-> C-5 <-> C-3 <-> A-3 <-> C-4 <-> --- <-> --- <-> C-6 <-> A-2 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5']
# Status Agent 1 at position 3: 2
# window product:  ['C-7' 'A-7' 'A-6']
# workbench:  {'A-5': [2]}
# Status Agent 2 at position 7: 2
# ...
# Status Agent 1 at position 3: 2
# window product:  [None 'A-7' None]
# workbench:  {'A-3': [2]}
# Status Agent 2 at position 7: 0
# window product:  [None None 'A-6']
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  ['A-2' None None]
# workbench:  {'C-5': [1, 3]}
# Conveyor: --- <-> --- <-> A-7 <-> --- <-> --- <-> A-6 <-> --- <-> --- <-> --- <-> --- <-> --- <-> A-2
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7']
# Status Agent 1 at position 3: 0
# window product:  ['A-7' None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None 'A-6' None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'C-5': [1, 3]}
# Conveyor: A-2 <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> A-6 <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3']
# Status Agent 1 at position 3: 0
# window product:  [None None 'A-2']
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  ['A-6' None None]
# workbench:  {}
# Status Agent 3 at position 11: 2
# window product:  [None None None]
# workbench:  {'C-5': [3]}
# Conveyor: --- <-> A-2 <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> A-6 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3']
# Status Agent 1 at position 3: 0
# window product:  [None 'A-2' None]
# workbench:  {}
# Status Agent 2 at position 7: 1
# window product:  [None None 'A-7']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> A-2 <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 0
# window product:  ['A-2' None None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None 'A-7' None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> A-2 <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 1
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  ['A-7' None None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None 'A-7']
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> A-7 <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None 'A-7' None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> A-7 <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  ['A-7' None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> A-7
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: A-7 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 2
# window product:  [None None 'A-7']
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> A-7 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 2
# window product:  [None 'A-7' None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> A-7 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 2
# window product:  ['A-7' None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-6': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 0
# window product:  [None None 'A-7']
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 0
# window product:  [None 'A-7' None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 0
# window product:  ['A-7' None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> A-7 <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 1
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 2
# window product:  [None None None]
# workbench:  {'A-2': [2]}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6']
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6', 'A-2']
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6', 'A-2']
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6', 'A-2']
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 2
# window product:  [None None None]
# workbench:  {'A-7': [2]}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6', 'A-2']
# Status Agent 1 at position 3: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 2 at position 7: 0
# window product:  [None None None]
# workbench:  {}
# Status Agent 3 at position 11: 0
# window product:  [None None None]
# workbench:  {}
# Conveyor: --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> --- <-> ---
# Buffer: []
# Completed Products: ['C-1', 'B-1', 'B-3', 'B-2', 'A-1', 'C-2', 'B-4', 'A-4', 'B-6', 'B-5', 'B-7', 'C-6', 'A-5', 'C-3', 'C-4', 'C-7', 'A-3', 'C-5', 'A-6', 'A-2', 'A-7']
# Episode complete. Total Reward: 104.08333333333347 jumlah step: 188 total product completed: 21
# rewards: {1: 104.08333333333347}
# makespan: {1: 188}
# selesai
