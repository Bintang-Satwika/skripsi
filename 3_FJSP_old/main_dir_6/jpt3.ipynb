# %%
import numpy as np
import random
import gymnasium as gym
from gymnasium import spaces

##############################################
# Agent class – represents a robot with fixed position
##############################################
class Agent:
    def __init__(self, agent_id: int, position: int, operation_capability: list, speed: float, window_size: int, num_agents: int):
        self.id = agent_id
        self.position = position         # y_r: fixed position on the conveyor
        self.operation_capability = operation_capability  # e.g. [1,2]
        self.speed = speed
        self.window_size = window_size   # Number of sections the agent can observe
        self.num_agents = num_agents

        self.operation_now = 0           # O_{r,t}: current operation (0 means idle)
        self.status = 0                  # Agent's own status: 0=idle, 1=accept, 2=working, 3=completing
        self.window = [0] * window_size  # The observed job operations from the conveyor

        self.workbench = None            # Holds the job once accepted

    def build_state(self, global_status):
        """
        Build the observation vector ω₍r,t₎ as defined in the paper:
          [ y_r, O_r (2 values), O_{r,t}, Z_t (num_agents values), window (window_size values) ]
        For 3 agents and window_size 3, this gives: 1 + 2 + 1 + 3 + 3 = 10 dimensions.
        """
        state = np.array([self.position] +
                         self.operation_capability +
                         [self.operation_now] +
                         global_status +
                         self.window, dtype=np.float32)
        return state

    def processing_time(self, base_time):
        return int(np.ceil(base_time / self.speed))

##############################################
# CircularConveyor class – simulates the conveyor belt
##############################################
class CircularConveyor:
    def __init__(self, num_sections: int, max_capacity: float):
        self.num_sections = num_sections
        self.max_capacity = max_capacity  # e.g., 0.75
        self.conveyor = [None] * num_sections  # Initialize with empty slots
        self.buffer = []  # Buffer for jobs waiting to be loaded
        self.job_counter = 0

    def add_job(self):
        """
        Generate a new job from a fixed product library.
        Product A: [1,2], Product B: [2,3], Product C: [1,3]
        """
        self.job_counter += 1
        product = random.choice(["A", "B", "C"])
        if product == "A":
            ops = [1, 2]
        elif product == "B":
            ops = [2, 3]
        else:
            ops = [1, 3]
        job = (f"{product}-{self.job_counter}", ops)
        self.buffer.append(job)

    def load_job(self):
        """
        Load a job from the buffer into section 0 if:
          - The number of jobs on the conveyor is below max_capacity * num_sections.
          - Section 0 is empty.
        """
        current_jobs = sum(1 for x in self.conveyor if x is not None)
        if self.buffer and current_jobs < self.max_capacity * self.num_sections and self.conveyor[0] is None:
            self.conveyor[0] = self.buffer.pop(0)

    def move(self):
        """
        Move the conveyor one step (circularly).
        """
        last = self.conveyor[-1]
        for i in range(self.num_sections - 1, 0, -1):
            self.conveyor[i] = self.conveyor[i - 1]
        self.conveyor[0] = last

    def update(self):
        """
        Update the conveyor: move, possibly add a new job, and load job if possible.
        """
        self.move()
        if random.random() < 0.3:
            self.add_job()
        self.load_job()

    def get_window_values(self, position, window_size):
        """
        Return a list of the first operation of each job in the agent's observation window.
        For each section from position to position - window_size + 1 (wrapping around), 
        return 0 if empty; otherwise, return the first operation of the job.
        """
        values = []
        for r in range(window_size):
            idx = (position - r) % self.num_sections
            job = self.conveyor[idx]
            if job is None:
                values.append(0)
            else:
                values.append(job[1][0])
        return values

##############################################
# FJSPEnv – Gymnasium Environment for FJSP (matching the paper)
##############################################
class FJSPEnv(gym.Env):
    def __init__(self, window_size: int, num_agents: int, max_steps: int):
        super(FJSPEnv, self).__init__()
        self.window_size = window_size  # 3
        self.num_agents = num_agents    # 3
        self.max_steps = max_steps
        self.step_count = 0

        # Initialize the conveyor with 12 sections and max capacity.
        self.num_sections = 12
        self.conveyor = CircularConveyor(self.num_sections, max_capacity=0.75)

        # Create agents at fixed positions.
        self.agent_positions = [3, 7, 11]
        self.agent_capabilities = [[1, 2], [2, 3], [1, 3]]
        self.agent_speeds = [1, 2, 3]
        self.agents = []
        for i in range(self.num_agents):
            agent = Agent(
                agent_id=i + 1,
                position=self.agent_positions[i],
                operation_capability=self.agent_capabilities[i],
                speed=self.agent_speeds[i],
                window_size=self.window_size,
                num_agents=self.num_agents
            )
            self.agents.append(agent)

        # Global status vector: each agent's status.
        self.global_status = [agent.status for agent in self.agents]

        # Define observation space: 10-dimensional per agent.
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.num_agents, 10), dtype=np.float32)
        # Define action space: 0=ACCEPT, 1=WAIT_1, 2=WAIT_2, 3=DECLINE, 4=CONTINUE.
        self.action_space = spaces.MultiDiscrete([5] * self.num_agents)

    def _get_observation(self):
        """
        For each agent, update its window from the conveyor and build its state vector.
        """
        self.global_status = [agent.status for agent in self.agents]
        obs = []
        for agent in self.agents:
            agent.window = self.conveyor.get_window_values(agent.position, self.window_size)
            obs.append(agent.build_state(self.global_status))
        return np.array(obs)

    def reset(self, seed=None, options=None):
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)
        self.step_count = 0
        self.conveyor = CircularConveyor(self.num_sections, max_capacity=0.75)
        # Preload some jobs.
        for _ in range(3):
            self.conveyor.add_job()
        self.conveyor.load_job()
        for agent in self.agents:
            agent.operation_now = 0
            agent.status = 0
            agent.workbench = None
        return self._get_observation(), {}

    def step(self, actions):
        """
        Process a step given actions for each agent.
        Actions: list of integers in {0,1,2,3,4} corresponding to:
          0: ACCEPT – pick up job at current section.
          1: WAIT_1 – wait for job at position y_r - 1.
          2: WAIT_2 – wait for job at position y_r - 2.
          3: DECLINE – reject the job at current section.
          4: CONTINUE – do nothing.
        """
        reward = 0.0
        # Process actions for each agent.
        for i, agent in enumerate(self.agents):
            act = actions[i]
            # If the agent is idle:
            if agent.status == 0:
                if act == 0:  # ACCEPT
                    job = self.conveyor.conveyor[agent.position]
                    if job is not None:
                        agent.workbench = job
                        agent.operation_now = job[1][0]  # First operation required.
                        agent.status = 2  # Working.
                        # Set a processing time based on a base time; here we choose 24 for op1, 18 for op2, etc.
                        base_time = 24 if agent.operation_now == 1 else 18
                        agent.processing_time_remaining = agent.processing_time(base_time)
                        self.conveyor.conveyor[agent.position] = None
                    else:
                        reward -= 1  # Penalize if no job available.
                elif act in [1, 2]:  # WAIT actions.
                    factor = 2.0 if act == 1 else 3.0
                    reward += 0.5 / factor  # Small reward for waiting (encouraging long-term return).
                    # Agent remains idle.
                    agent.status = 0
                elif act == 3:  # DECLINE.
                    self.conveyor.conveyor[agent.position] = None
                    agent.status = 0
                    reward -= 0.5
                elif act == 4:  # CONTINUE.
                    pass
            else:
                # If agent is busy (working), then process its job.
                if agent.status == 2:
                    if agent.processing_time_remaining > 0:
                        agent.processing_time_remaining -= 1
                        reward += agent.speed / sum(self.agent_speeds)
                    if agent.processing_time_remaining == 0:
                        # Job complete.
                        agent.status = 3  # Completing.
                        agent.workbench = None
                        agent.operation_now = 0
                        agent.status = 0  # Reset to idle.
                        reward += 4  # Reward for job completion.
        # Update environment dynamics.
        self.conveyor.update()
        self.step_count += 1
        reward -= 1  # Timestep penalty.
        done = self.step_count >= self.max_steps
        obs = self._get_observation()
        info = {"actions": actions}
        return obs, reward, done, False, info

    def render(self):
        print(f"Step: {self.step_count}")
        for agent in self.agents:
            print(f"Agent {agent.id} at pos {agent.position}: Status {agent.status}, Operation {agent.operation_now}, Workbench {agent.workbench}, Window {agent.window}")
        conv_str = " | ".join([str(j[0]) if j is not None else "---" for j in self.conveyor.conveyor])
        print("Conveyor:", conv_str)
        print("-" * 40)

##############################################
# Main function to test the environment
##############################################
def main():
    env = FJSPEnv(window_size=3, num_agents=3, max_steps=300)
    obs, _ = env.reset(seed=42)
    print("Initial Observations:")
    print(obs)
    done = False
    steps = 0
    while not done:
        actions = env.action_space.sample()
        print(f"\nStep {steps+1}, Actions: {actions}")
        obs, reward, done, truncated, info = env.step(actions)
        done = done or truncated
        print("Observations:")
        print(obs)
        print("Reward:", reward)
        env.render()
        steps += 1

if __name__ == '__main__':
    main()
# Out:
# Initial Observations:
# [[ 3.  1.  2.  0.  0.  0.  0.  0.  0.  0.]
#  [ 7.  2.  3.  0.  0.  0.  0.  0.  0.  0.]
#  [11.  1.  3.  0.  0.  0.  0.  0.  0.  0.]]
#
# Step 1, Actions: [0 2 2]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  0.  0.  0.  1.]
#  [ 7.  2.  3.  0.  0.  0.  0.  0.  0.  0.]
#  [11.  1.  3.  0.  0.  0.  0.  0.  0.  0.]]
# Reward: -1.6666666666666667
# Step: 1
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: A-2 | C-1 | --- | --- | --- | --- | --- | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 2, Actions: [3 1 4]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  0.  0.  1.  1.]
#  [ 7.  2.  3.  0.  0.  0.  0.  0.  0.  0.]
#  [11.  1.  3.  0.  0.  0.  0.  0.  0.  0.]]
# Reward: -1.25
# Step: 2
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [0, 1, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: A-3 | A-2 | C-1 | --- | --- | --- | --- | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 3, Actions: [4 1 0]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  0.  1.  1.  1.]
#  [ 7.  2.  3.  0.  0.  0.  0.  0.  0.  0.]
#  [11.  1.  3.  0.  0.  0.  0.  0.  0.  0.]]
# Reward: -1.75
# Step: 3
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 1, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: A-4 | A-3 | A-2 | C-1 | --- | --- | --- | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 4, Actions: [0 3 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  1.  1.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  0.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  0.]]
# Reward: -2.0
# Step: 4
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [1, 1, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: --- | A-4 | A-3 | A-2 | --- | --- | --- | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 5, Actions: [4 3 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  1.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  0.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  0.]]
# Reward: -1.3333333333333335
# Step: 5
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [1, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: --- | --- | A-4 | A-3 | A-2 | --- | --- | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 6, Actions: [0 0 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  0.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  0.]]
# Reward: -1.5833333333333335
# Step: 6
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: B-5 | --- | --- | A-4 | A-3 | A-2 | --- | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 7, Actions: [2 1 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  2.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  1.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  0.]]
# Reward: -0.33333333333333337
# Step: 7
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 0, 2]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 1, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: A-6 | B-5 | --- | --- | A-4 | A-3 | A-2 | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 8, Actions: [4 1 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  2.  1.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  1.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  0.]]
# Reward: -0.33333333333333337
# Step: 8
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 2, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 1, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: C-7 | A-6 | B-5 | --- | --- | A-4 | A-3 | A-2 | --- | --- | --- | ---
# ----------------------------------------
#
# Step 9, Actions: [3 3 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  2.  1.  1.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  1.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  0.]]
# Reward: -1.3333333333333335
# Step: 9
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [2, 1, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: --- | C-7 | A-6 | B-5 | --- | --- | A-4 | A-3 | --- | --- | --- | ---
# ----------------------------------------
#
# Step 10, Actions: [2 2 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  1.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  0.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  0.]]
# Reward: -1.1666666666666667
# Step: 10
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [1, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: --- | --- | C-7 | A-6 | B-5 | --- | --- | A-4 | A-3 | --- | --- | ---
# ----------------------------------------
#
# Step 11, Actions: [1 2 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  0.  2.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  1.]]
# Reward: -0.6666666666666667
# Step: 11
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Conveyor: --- | --- | --- | C-7 | A-6 | B-5 | --- | --- | A-4 | A-3 | --- | ---
# ----------------------------------------
#
# Step 12, Actions: [3 2 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  2.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  1.  1.]]
# Reward: -0.41666666666666674
# Step: 12
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 2, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 1]
# Conveyor: --- | --- | --- | --- | C-7 | A-6 | B-5 | --- | --- | A-4 | A-3 | ---
# ----------------------------------------
#
# Step 13, Actions: [3 3 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  2.  1.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  1.  1.  0.]]
# Reward: -1.0833333333333335
# Step: 13
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [2, 1, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 1, 0]
# Conveyor: --- | --- | --- | --- | --- | C-7 | A-6 | B-5 | --- | --- | A-4 | A-3
# ----------------------------------------
#
# Step 14, Actions: [0 1 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  1.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  1.  0.  0.]]
# Reward: -0.5833333333333334
# Step: 14
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Conveyor: A-3 | --- | --- | --- | --- | --- | C-7 | A-6 | B-5 | --- | --- | A-4
# ----------------------------------------
#
# Step 15, Actions: [1 2 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  1.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  0.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  2.]]
# Reward: -0.6666666666666667
# Step: 15
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 0, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 2]
# Conveyor: A-4 | A-3 | --- | --- | --- | --- | --- | C-7 | A-6 | B-5 | --- | ---
# ----------------------------------------
#
# Step 16, Actions: [4 0 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  0.  1.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  0.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  2.  1.]]
# Reward: -0.6666666666666667
# Step: 16
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 1, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [0, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 2, 1]
# Conveyor: A-8 | A-4 | A-3 | --- | --- | --- | --- | --- | --- | A-6 | B-5 | ---
# ----------------------------------------
#
# Step 17, Actions: [3 3 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  1.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  0.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  2.  1.  0.]]
# Reward: -0.33333333333333337
# Step: 17
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [1, 1, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [0, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [2, 1, 0]
# Conveyor: B-9 | A-8 | A-4 | A-3 | --- | --- | --- | --- | --- | --- | A-6 | B-5
# ----------------------------------------
#
# Step 18, Actions: [2 1 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  1.  1.  2.]
#  [ 7.  2.  3.  1.  2.  2.  2.  0.  0.  0.]
#  [11.  1.  3.  2.  2.  2.  2.  1.  0.  0.]]
# Reward: -0.5
# Step: 18
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [1, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [0, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 2, Workbench ('B-5', [2, 3]), Window [1, 0, 0]
# Conveyor: --- | B-9 | A-8 | A-4 | A-3 | --- | --- | --- | --- | --- | --- | A-6
# ----------------------------------------
#
# Step 19, Actions: [2 1 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  1.  2.  0.]
#  [ 7.  2.  3.  1.  2.  2.  2.  0.  0.  1.]
#  [11.  1.  3.  2.  2.  2.  2.  0.  0.  0.]]
# Reward: 0.0
# Step: 19
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [1, 2, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [0, 0, 1]
# Agent 3 at pos 11: Status 2, Operation 2, Workbench ('B-5', [2, 3]), Window [0, 0, 0]
# Conveyor: A-6 | --- | B-9 | A-8 | A-4 | A-3 | --- | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 20, Actions: [3 2 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  2.  0.  1.]
#  [ 7.  2.  3.  1.  2.  2.  2.  0.  1.  1.]
#  [11.  1.  3.  2.  2.  2.  2.  0.  0.  0.]]
# Reward: 0.0
# Step: 20
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [2, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [0, 1, 1]
# Agent 3 at pos 11: Status 2, Operation 2, Workbench ('B-5', [2, 3]), Window [0, 0, 0]
# Conveyor: B-10 | A-6 | --- | B-9 | A-8 | A-4 | A-3 | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 21, Actions: [1 2 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  1.  2.]
#  [ 7.  2.  3.  1.  2.  2.  2.  1.  1.  1.]
#  [11.  1.  3.  2.  2.  2.  2.  0.  0.  0.]]
# Reward: 0.0
# Step: 21
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [1, 1, 1]
# Agent 3 at pos 11: Status 2, Operation 2, Workbench ('B-5', [2, 3]), Window [0, 0, 0]
# Conveyor: B-11 | B-10 | A-6 | --- | B-9 | A-8 | A-4 | A-3 | --- | --- | --- | ---
# ----------------------------------------
#
# Step 22, Actions: [3 4 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  1.  2.  2.]
#  [ 7.  2.  3.  1.  2.  2.  2.  1.  1.  2.]
#  [11.  1.  3.  2.  2.  2.  2.  0.  0.  0.]]
# Reward: 0.0
# Step: 22
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [1, 2, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [1, 1, 2]
# Agent 3 at pos 11: Status 2, Operation 2, Workbench ('B-5', [2, 3]), Window [0, 0, 0]
# Conveyor: B-12 | B-11 | B-10 | A-6 | --- | B-9 | A-8 | A-4 | A-3 | --- | --- | ---
# ----------------------------------------
#
# Step 23, Actions: [1 2 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  2.  2.  2.]
#  [ 7.  2.  3.  1.  2.  2.  2.  1.  2.  0.]
#  [11.  1.  3.  2.  2.  2.  2.  0.  0.  1.]]
# Reward: 0.0
# Step: 23
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [2, 2, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [1, 2, 0]
# Agent 3 at pos 11: Status 2, Operation 2, Workbench ('B-5', [2, 3]), Window [0, 0, 1]
# Conveyor: --- | B-12 | B-11 | B-10 | A-6 | --- | B-9 | A-8 | A-4 | A-3 | --- | ---
# ----------------------------------------
#
# Step 24, Actions: [1 0 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  2.  0.]
#  [ 7.  2.  3.  1.  2.  2.  0.  2.  0.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  1.  1.]]
# Reward: 4.0
# Step: 24
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [2, 2, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [2, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 1]
# Conveyor: --- | --- | B-12 | B-11 | B-10 | A-6 | --- | B-9 | A-8 | A-4 | A-3 | ---
# ----------------------------------------
#
# Step 25, Actions: [0 2 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  0.  0.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  1.  2.]
#  [11.  1.  3.  0.  2.  2.  0.  1.  1.  1.]]
# Reward: -1.5
# Step: 25
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [2, 0, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [0, 1, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 1, 1]
# Conveyor: --- | --- | --- | B-12 | B-11 | B-10 | A-6 | --- | B-9 | A-8 | A-4 | A-3
# ----------------------------------------
#
# Step 26, Actions: [2 2 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  0.  0.  0.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  2.  2.]
#  [11.  1.  3.  0.  2.  2.  0.  1.  1.  2.]]
# Reward: -0.5
# Step: 26
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 0, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [1, 2, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 1, 2]
# Conveyor: A-3 | --- | --- | --- | B-12 | B-11 | B-10 | A-6 | --- | B-9 | A-8 | A-4
# ----------------------------------------
#
# Step 27, Actions: [2 4 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  0.  1.]
#  [ 7.  2.  3.  1.  2.  2.  2.  2.  2.  2.]
#  [11.  1.  3.  1.  2.  2.  2.  1.  2.  0.]]
# Reward: -0.5
# Step: 27
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('C-1', [1, 3]), Window [0, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('C-7', [1, 3]), Window [2, 2, 2]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-4', [1, 2]), Window [1, 2, 0]
# Conveyor: --- | A-3 | --- | --- | --- | B-12 | B-11 | B-10 | A-6 | --- | B-9 | A-8
# ----------------------------------------
#
# Step 28, Actions: [3 3 2]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  0.  1.  0.]
#  [ 7.  2.  3.  0.  0.  0.  2.  2.  2.  0.]
#  [11.  1.  3.  1.  0.  0.  2.  2.  0.  1.]]
# Reward: 8.0
# Step: 28
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [2, 2, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-4', [1, 2]), Window [2, 0, 1]
# Conveyor: A-8 | --- | A-3 | --- | --- | --- | B-12 | B-11 | B-10 | A-6 | --- | B-9
# ----------------------------------------
#
# Step 29, Actions: [2 0 2]
# Observations:
# [[ 3.  1.  2.  0.  0.  2.  2.  1.  0.  1.]
#  [ 7.  2.  3.  2.  0.  2.  2.  2.  0.  0.]
#  [11.  1.  3.  1.  0.  2.  2.  0.  1.  2.]]
# Reward: -0.33333333333333337
# Step: 29
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-11', [2, 3]), Window [2, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-4', [1, 2]), Window [0, 1, 2]
# Conveyor: B-9 | A-8 | --- | A-3 | --- | --- | --- | B-12 | --- | B-10 | A-6 | ---
# ----------------------------------------
#
# Step 30, Actions: [2 4 4]
# Observations:
# [[ 3.  1.  2.  0.  0.  2.  2.  0.  1.  2.]
#  [ 7.  2.  3.  2.  0.  2.  2.  0.  0.  0.]
#  [11.  1.  3.  1.  0.  2.  2.  1.  2.  0.]]
# Reward: 0.0
# Step: 30
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [0, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-11', [2, 3]), Window [0, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-4', [1, 2]), Window [1, 2, 0]
# Conveyor: --- | B-9 | A-8 | --- | A-3 | --- | --- | --- | B-12 | --- | B-10 | A-6
# ----------------------------------------
#
# Step 31, Actions: [4 1 4]
# Observations:
# [[ 3.  1.  2.  0.  0.  2.  2.  1.  2.  0.]
#  [ 7.  2.  3.  2.  0.  2.  2.  0.  0.  1.]
#  [11.  1.  3.  1.  0.  2.  2.  2.  0.  2.]]
# Reward: -0.16666666666666674
# Step: 31
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 2, 0]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-11', [2, 3]), Window [0, 0, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-4', [1, 2]), Window [2, 0, 2]
# Conveyor: A-6 | --- | B-9 | A-8 | --- | A-3 | --- | --- | --- | B-12 | --- | B-10
# ----------------------------------------
#
# Step 32, Actions: [0 0 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  2.  0.  1.]
#  [ 7.  2.  3.  2.  2.  2.  2.  0.  1.  0.]
#  [11.  1.  3.  1.  2.  2.  2.  0.  2.  0.]]
# Reward: -0.16666666666666674
# Step: 32
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [2, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-11', [2, 3]), Window [0, 1, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-4', [1, 2]), Window [0, 2, 0]
# Conveyor: B-10 | A-6 | --- | B-9 | --- | --- | A-3 | --- | --- | --- | B-12 | ---
# ----------------------------------------
#
# Step 33, Actions: [3 2 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  1.  2.]
#  [ 7.  2.  3.  2.  2.  2.  2.  1.  0.  0.]
#  [11.  1.  3.  1.  2.  2.  2.  2.  0.  0.]]
# Reward: 0.0
# Step: 33
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-11', [2, 3]), Window [1, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-4', [1, 2]), Window [2, 0, 0]
# Conveyor: --- | B-10 | A-6 | --- | B-9 | --- | --- | A-3 | --- | --- | --- | B-12
# ----------------------------------------
#
# Step 34, Actions: [4 1 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  1.  2.  0.]
#  [ 7.  2.  3.  2.  2.  2.  2.  0.  0.  2.]
#  [11.  1.  3.  1.  2.  2.  2.  0.  0.  0.]]
# Reward: 0.0
# Step: 34
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [1, 2, 0]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-11', [2, 3]), Window [0, 0, 2]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-4', [1, 2]), Window [0, 0, 0]
# Conveyor: B-12 | --- | B-10 | A-6 | --- | B-9 | --- | --- | A-3 | --- | --- | ---
# ----------------------------------------
#
# Step 35, Actions: [4 1 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  0.  2.]
#  [ 7.  2.  3.  2.  2.  2.  0.  0.  2.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  1.]]
# Reward: 4.0
# Step: 35
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [2, 0, 2]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-11', [2, 3]), Window [0, 2, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Conveyor: A-13 | B-12 | --- | B-10 | A-6 | --- | B-9 | --- | --- | A-3 | --- | ---
# ----------------------------------------
#
# Step 36, Actions: [1 2 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  0.  2.  1.]
#  [ 7.  2.  3.  2.  2.  2.  0.  2.  0.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  1.  0.]]
# Reward: -0.25
# Step: 36
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 2, 1]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-11', [2, 3]), Window [2, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Conveyor: --- | A-13 | B-12 | --- | B-10 | A-6 | --- | B-9 | --- | --- | A-3 | ---
# ----------------------------------------
#
# Step 37, Actions: [0 1 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  1.  0.]
#  [ 7.  2.  3.  2.  2.  2.  0.  0.  1.  2.]
#  [11.  1.  3.  0.  2.  2.  0.  1.  0.  0.]]
# Reward: -0.5
# Step: 37
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [2, 1, 0]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-11', [2, 3]), Window [0, 1, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Conveyor: --- | --- | A-13 | B-12 | --- | B-10 | A-6 | --- | B-9 | --- | --- | A-3
# ----------------------------------------
#
# Step 38, Actions: [4 1 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  2.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  2.]]
# Reward: 3.5
# Step: 38
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 2, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 2]
# Conveyor: A-3 | --- | --- | A-13 | B-12 | --- | B-10 | A-6 | --- | B-9 | --- | ---
# ----------------------------------------
#
# Step 39, Actions: [1 1 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  1.]
#  [ 7.  2.  3.  0.  2.  0.  0.  2.  0.  2.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  2.  0.]]
# Reward: -1.0833333333333335
# Step: 39
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 0, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [2, 0, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 2, 0]
# Conveyor: --- | A-3 | --- | --- | A-13 | B-12 | --- | B-10 | A-6 | --- | B-9 | ---
# ----------------------------------------
#
# Step 40, Actions: [2 3 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  1.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  2.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  2.  0.  1.]]
# Reward: -1.1666666666666667
# Step: 40
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 2, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [2, 0, 1]
# Conveyor: --- | --- | A-3 | --- | --- | A-13 | B-12 | --- | --- | A-6 | --- | B-9
# ----------------------------------------
#
# Step 41, Actions: [1 3 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  2.  1.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  1.  0.]]
# Reward: -1.8333333333333335
# Step: 41
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [2, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Conveyor: --- | --- | --- | A-3 | --- | --- | A-13 | B-12 | --- | --- | A-6 | ---
# ----------------------------------------
#
# Step 42, Actions: [0 3 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  0.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  1.  0.  0.]]
# Reward: -1.1666666666666667
# Step: 42
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Conveyor: B-14 | --- | --- | --- | A-3 | --- | --- | A-13 | --- | --- | --- | A-6
# ----------------------------------------
#
# Step 43, Actions: [3 0 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  0.  0.  2.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  0.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  0.]]
# Reward: -0.5833333333333334
# Step: 43
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 0, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [0, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: A-6 | B-14 | --- | --- | --- | A-3 | --- | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 44, Actions: [1 3 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  0.  2.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  1.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  0.]]
# Reward: -0.5
# Step: 44
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 2, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [0, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: B-15 | A-6 | B-14 | --- | --- | --- | A-3 | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 45, Actions: [1 3 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  1.  2.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  0.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  0.]]
# Reward: -0.5
# Step: 45
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [2, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [1, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: --- | B-15 | A-6 | B-14 | --- | --- | --- | A-3 | --- | --- | --- | ---
# ----------------------------------------
#
# Step 46, Actions: [3 0 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  2.  0.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  0.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  0.]]
# Reward: -0.33333333333333337
# Step: 46
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [1, 2, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [0, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: C-16 | --- | B-15 | A-6 | B-14 | --- | --- | --- | A-3 | --- | --- | ---
# ----------------------------------------
#
# Step 47, Actions: [4 4 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  0.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  0.  2.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  1.]]
# Reward: -0.5
# Step: 47
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [2, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [0, 0, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Conveyor: C-17 | C-16 | --- | B-15 | A-6 | B-14 | --- | --- | --- | A-3 | --- | ---
# ----------------------------------------
#
# Step 48, Actions: [1 0 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  0.  1.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  2.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  1.  0.]]
# Reward: -1.0
# Step: 48
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 1, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [0, 2, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Conveyor: B-18 | C-17 | C-16 | --- | B-15 | A-6 | B-14 | --- | --- | --- | A-3 | ---
# ----------------------------------------
#
# Step 49, Actions: [4 3 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  1.  2.]
#  [ 7.  2.  3.  1.  2.  2.  0.  2.  1.  2.]
#  [11.  1.  3.  0.  2.  2.  0.  1.  0.  0.]]
# Reward: -0.5
# Step: 49
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [1, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [2, 1, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Conveyor: --- | B-18 | C-17 | C-16 | --- | B-15 | A-6 | B-14 | --- | --- | --- | A-3
# ----------------------------------------
#
# Step 50, Actions: [1 0 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  2.  0.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  2.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  0.]]
# Reward: -0.5
# Step: 50
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [1, 2, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [1, 2, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: A-3 | --- | B-18 | C-17 | C-16 | --- | B-15 | A-6 | B-14 | --- | --- | ---
# ----------------------------------------
#
# Step 51, Actions: [3 4 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  0.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  2.  0.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  2.]]
# Reward: -1.5
# Step: 51
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [2, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [2, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 2]
# Conveyor: --- | A-3 | --- | B-18 | C-17 | C-16 | --- | B-15 | A-6 | B-14 | --- | ---
# ----------------------------------------
#
# Step 52, Actions: [2 3 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  0.  1.  0.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  1.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  2.  1.]]
# Reward: -1.5
# Step: 52
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 1, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [0, 1, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 2, 1]
# Conveyor: --- | --- | A-3 | --- | B-18 | C-17 | C-16 | --- | B-15 | A-6 | B-14 | ---
# ----------------------------------------
#
# Step 53, Actions: [2 3 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  0.  0.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  1.  2.]
#  [11.  1.  3.  0.  2.  2.  0.  2.  1.  2.]]
# Reward: -0.33333333333333337
# Step: 53
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [1, 1, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [2, 1, 2]
# Conveyor: --- | --- | --- | A-3 | --- | B-18 | C-17 | C-16 | --- | B-15 | A-6 | B-14
# ----------------------------------------
#
# Step 54, Actions: [4 1 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  0.  0.  0.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  2.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  1.  2.  0.]]
# Reward: -0.5
# Step: 54
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 0, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-13', [1, 2]), Window [1, 2, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 2, 0]
# Conveyor: B-14 | --- | --- | --- | A-3 | --- | B-18 | C-17 | C-16 | --- | B-15 | A-6
# ----------------------------------------
#
# Step 55, Actions: [4 4 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  2.]
#  [ 7.  2.  3.  0.  2.  0.  0.  2.  0.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  2.  0.  1.]]
# Reward: 3.5
# Step: 55
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-8', [1, 2]), Window [0, 0, 2]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [2, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [2, 0, 1]
# Conveyor: A-6 | B-14 | --- | --- | --- | A-3 | --- | B-18 | C-17 | C-16 | --- | B-15
# ----------------------------------------
#
# Step 56, Actions: [2 3 3]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  0.  0.  2.  1.]
#  [ 7.  2.  3.  0.  0.  0.  0.  0.  1.  0.]
#  [11.  1.  3.  0.  0.  0.  0.  0.  1.  1.]]
# Reward: 2.166666666666667
# Step: 56
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [0, 2, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 1]
# Conveyor: A-19 | A-6 | B-14 | --- | --- | --- | A-3 | --- | --- | C-17 | C-16 | ---
# ----------------------------------------
#
# Step 57, Actions: [2 1 0]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  0.  2.  1.  1.]
#  [ 7.  2.  3.  0.  0.  0.  0.  1.  0.  0.]
#  [11.  1.  3.  0.  0.  0.  0.  1.  1.  0.]]
# Reward: -1.5833333333333335
# Step: 57
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [2, 1, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 1, 0]
# Conveyor: --- | A-19 | A-6 | B-14 | --- | --- | --- | A-3 | --- | --- | C-17 | C-16
# ----------------------------------------
#
# Step 58, Actions: [2 1 0]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  1.  1.  0.]
#  [ 7.  2.  3.  0.  0.  0.  2.  0.  0.  0.]
#  [11.  1.  3.  1.  0.  0.  2.  1.  0.  0.]]
# Reward: -0.5833333333333334
# Step: 58
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-16', [1, 3]), Window [1, 0, 0]
# Conveyor: --- | --- | A-19 | A-6 | B-14 | --- | --- | --- | A-3 | --- | --- | C-17
# ----------------------------------------
#
# Step 59, Actions: [3 1 3]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  1.  0.  0.]
#  [ 7.  2.  3.  0.  0.  0.  2.  0.  0.  2.]
#  [11.  1.  3.  1.  0.  0.  2.  0.  0.  1.]]
# Reward: -0.75
# Step: 59
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 2]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-16', [1, 3]), Window [0, 0, 1]
# Conveyor: C-17 | --- | --- | A-19 | --- | B-14 | --- | --- | --- | A-3 | --- | ---
# ----------------------------------------
#
# Step 60, Actions: [2 2 2]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  0.  0.  1.]
#  [ 7.  2.  3.  0.  0.  0.  2.  0.  2.  0.]
#  [11.  1.  3.  1.  0.  0.  2.  0.  1.  0.]]
# Reward: -0.16666666666666674
# Step: 60
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 2, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-16', [1, 3]), Window [0, 1, 0]
# Conveyor: C-20 | C-17 | --- | --- | A-19 | --- | B-14 | --- | --- | --- | A-3 | ---
# ----------------------------------------
#
# Step 61, Actions: [1 0 3]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  0.  1.  1.]
#  [ 7.  2.  3.  0.  0.  0.  2.  2.  0.  1.]
#  [11.  1.  3.  1.  0.  0.  2.  1.  0.  0.]]
# Reward: -1.25
# Step: 61
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [0, 1, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [2, 0, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-16', [1, 3]), Window [1, 0, 0]
# Conveyor: --- | C-20 | C-17 | --- | --- | A-19 | --- | B-14 | --- | --- | --- | A-3
# ----------------------------------------
#
# Step 62, Actions: [2 2 3]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  1.  1.  0.]
#  [ 7.  2.  3.  0.  0.  0.  2.  0.  1.  0.]
#  [11.  1.  3.  1.  0.  0.  2.  0.  0.  0.]]
# Reward: -0.16666666666666674
# Step: 62
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-16', [1, 3]), Window [0, 0, 0]
# Conveyor: A-3 | --- | C-20 | C-17 | --- | --- | A-19 | --- | B-14 | --- | --- | ---
# ----------------------------------------
#
# Step 63, Actions: [2 1 0]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  1.  0.  1.]
#  [ 7.  2.  3.  0.  0.  0.  2.  1.  0.  0.]
#  [11.  1.  3.  1.  0.  0.  2.  0.  0.  2.]]
# Reward: -0.08333333333333337
# Step: 63
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 0, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-16', [1, 3]), Window [0, 0, 2]
# Conveyor: --- | A-3 | --- | C-20 | C-17 | --- | --- | A-19 | --- | B-14 | --- | ---
# ----------------------------------------
#
# Step 64, Actions: [2 1 0]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  0.  1.  0.]
#  [ 7.  2.  3.  0.  0.  0.  2.  0.  0.  1.]
#  [11.  1.  3.  1.  0.  0.  2.  0.  2.  0.]]
# Reward: -0.08333333333333337
# Step: 64
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-16', [1, 3]), Window [0, 2, 0]
# Conveyor: --- | --- | A-3 | --- | C-20 | C-17 | --- | --- | A-19 | --- | B-14 | ---
# ----------------------------------------
#
# Step 65, Actions: [4 4 3]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  1.  0.  0.]
#  [ 7.  2.  3.  0.  0.  0.  2.  0.  1.  1.]
#  [11.  1.  3.  1.  0.  0.  2.  2.  0.  1.]]
# Reward: -0.5
# Step: 65
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 1, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-16', [1, 3]), Window [2, 0, 1]
# Conveyor: --- | --- | --- | A-3 | --- | C-20 | C-17 | --- | --- | A-19 | --- | B-14
# ----------------------------------------
#
# Step 66, Actions: [0 4 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  1.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  1.  0.]]
# Reward: 3.5
# Step: 66
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Conveyor: B-14 | --- | --- | --- | --- | --- | C-20 | C-17 | --- | --- | A-19 | ---
# ----------------------------------------
#
# Step 67, Actions: [3 2 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  2.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  0.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  1.  0.  0.]]
# Reward: -0.5
# Step: 67
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 0, 2]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Conveyor: A-21 | B-14 | --- | --- | --- | --- | --- | C-20 | C-17 | --- | --- | A-19
# ----------------------------------------
#
# Step 68, Actions: [1 3 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  2.  0.  2.  1.]
#  [ 7.  2.  3.  0.  2.  0.  2.  0.  0.  0.]
#  [11.  1.  3.  1.  2.  0.  2.  0.  0.  1.]]
# Reward: -1.3333333333333335
# Step: 68
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 2, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-19', [1, 2]), Window [0, 0, 1]
# Conveyor: --- | A-21 | B-14 | --- | --- | --- | --- | --- | --- | C-17 | --- | ---
# ----------------------------------------
#
# Step 69, Actions: [2 3 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  2.  2.  1.  0.]
#  [ 7.  2.  3.  0.  2.  0.  2.  0.  0.  0.]
#  [11.  1.  3.  1.  2.  0.  2.  0.  1.  0.]]
# Reward: -0.8333333333333334
# Step: 69
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [2, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-19', [1, 2]), Window [0, 1, 0]
# Conveyor: --- | --- | A-21 | B-14 | --- | --- | --- | --- | --- | --- | C-17 | ---
# ----------------------------------------
#
# Step 70, Actions: [2 0 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  2.  1.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  2.  0.  0.  0.]
#  [11.  1.  3.  1.  2.  0.  2.  1.  0.  0.]]
# Reward: -1.3333333333333335
# Step: 70
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-19', [1, 2]), Window [1, 0, 0]
# Conveyor: --- | --- | --- | A-21 | B-14 | --- | --- | --- | --- | --- | --- | C-17
# ----------------------------------------
#
# Step 71, Actions: [4 4 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  2.  0.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  2.  0.  0.  2.]
#  [11.  1.  3.  1.  2.  0.  2.  0.  0.  0.]]
# Reward: -0.33333333333333337
# Step: 71
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 2]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-19', [1, 2]), Window [0, 0, 0]
# Conveyor: C-17 | --- | --- | --- | A-21 | B-14 | --- | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 72, Actions: [0 2 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  2.  0.  0.  1.]
#  [ 7.  2.  3.  0.  2.  0.  2.  0.  2.  1.]
#  [11.  1.  3.  1.  2.  0.  2.  0.  0.  0.]]
# Reward: -0.16666666666666674
# Step: 72
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 0, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 2, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-19', [1, 2]), Window [0, 0, 0]
# Conveyor: --- | C-17 | --- | --- | --- | A-21 | B-14 | --- | --- | --- | --- | ---
# ----------------------------------------
#
# Step 73, Actions: [0 4 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  2.  0.  1.  0.]
#  [ 7.  2.  3.  0.  2.  0.  2.  2.  1.  0.]
#  [11.  1.  3.  1.  2.  0.  2.  0.  0.  0.]]
# Reward: -0.33333333333333337
# Step: 73
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [2, 1, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-19', [1, 2]), Window [0, 0, 0]
# Conveyor: --- | --- | C-17 | --- | --- | --- | A-21 | B-14 | --- | --- | --- | ---
# ----------------------------------------
#
# Step 74, Actions: [2 3 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  2.  1.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  2.  1.  0.  0.]
#  [11.  1.  3.  1.  2.  0.  2.  0.  0.  0.]]
# Reward: -0.8333333333333334
# Step: 74
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-19', [1, 2]), Window [0, 0, 0]
# Conveyor: B-22 | --- | --- | C-17 | --- | --- | --- | A-21 | --- | --- | --- | ---
# ----------------------------------------
#
# Step 75, Actions: [1 1 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  2.  0.  0.  2.]
#  [ 7.  2.  3.  0.  2.  0.  2.  0.  0.  0.]
#  [11.  1.  3.  1.  2.  0.  2.  0.  0.  0.]]
# Reward: -0.08333333333333337
# Step: 75
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 0, 2]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('A-19', [1, 2]), Window [0, 0, 0]
# Conveyor: A-23 | B-22 | --- | --- | C-17 | --- | --- | --- | A-21 | --- | --- | ---
# ----------------------------------------
#
# Step 76, Actions: [3 0 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  2.  1.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  0.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  1.]]
# Reward: 2.6666666666666665
# Step: 76
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 2, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Conveyor: --- | A-23 | B-22 | --- | --- | C-17 | --- | --- | --- | A-21 | --- | ---
# ----------------------------------------
#
# Step 77, Actions: [0 0 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  2.  1.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  1.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  1.  0.]]
# Reward: -1.6666666666666667
# Step: 77
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [2, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Conveyor: A-24 | --- | A-23 | B-22 | --- | --- | C-17 | --- | --- | --- | A-21 | ---
# ----------------------------------------
#
# Step 78, Actions: [3 4 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  0.  1.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  0.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  1.  0.  0.]]
# Reward: -1.8333333333333335
# Step: 78
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [1, 0, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Conveyor: --- | A-24 | --- | A-23 | B-22 | --- | --- | C-17 | --- | --- | --- | A-21
# ----------------------------------------
#
# Step 79, Actions: [3 1 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  1.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  0.  2.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  0.]]
# Reward: -1.0833333333333335
# Step: 79
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 1, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: --- | --- | A-24 | --- | A-23 | B-22 | --- | --- | C-17 | --- | --- | ---
# ----------------------------------------
#
# Step 80, Actions: [2 2 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  0.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  0.  2.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  0.  1.]]
# Reward: -0.41666666666666674
# Step: 80
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 2, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Conveyor: B-25 | --- | --- | A-24 | --- | A-23 | B-22 | --- | --- | C-17 | --- | ---
# ----------------------------------------
#
# Step 81, Actions: [1 2 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  0.  2.]
#  [ 7.  2.  3.  0.  2.  0.  0.  2.  1.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  0.  1.  0.]]
# Reward: -1.1666666666666667
# Step: 81
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 0, 2]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [2, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Conveyor: --- | B-25 | --- | --- | A-24 | --- | A-23 | B-22 | --- | --- | C-17 | ---
# ----------------------------------------
#
# Step 82, Actions: [0 2 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  2.  0.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  0.  1.]
#  [11.  1.  3.  0.  2.  0.  0.  1.  0.  0.]]
# Reward: -0.41666666666666674
# Step: 82
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 2, 0]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Conveyor: --- | --- | B-25 | --- | --- | A-24 | --- | A-23 | B-22 | --- | --- | C-17
# ----------------------------------------
#
# Step 83, Actions: [3 0 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  2.  0.  0.]
#  [ 7.  2.  3.  1.  2.  2.  2.  0.  1.  0.]
#  [11.  1.  3.  1.  2.  2.  2.  0.  0.  2.]]
# Reward: -0.8333333333333334
# Step: 83
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [2, 0, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-23', [1, 2]), Window [0, 1, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-17', [1, 3]), Window [0, 0, 2]
# Conveyor: C-26 | --- | --- | B-25 | --- | --- | A-24 | --- | --- | B-22 | --- | ---
# ----------------------------------------
#
# Step 84, Actions: [4 4 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  0.  1.]
#  [ 7.  2.  3.  1.  2.  2.  2.  1.  0.  0.]
#  [11.  1.  3.  1.  2.  2.  2.  0.  2.  0.]]
# Reward: 0.0
# Step: 84
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-23', [1, 2]), Window [1, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-17', [1, 3]), Window [0, 2, 0]
# Conveyor: --- | C-26 | --- | --- | B-25 | --- | --- | A-24 | --- | --- | B-22 | ---
# ----------------------------------------
#
# Step 85, Actions: [2 3 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  1.  0.]
#  [ 7.  2.  3.  1.  2.  2.  2.  0.  0.  2.]
#  [11.  1.  3.  1.  2.  2.  2.  2.  0.  0.]]
# Reward: 0.0
# Step: 85
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-3', [1, 2]), Window [0, 1, 0]
# ...
# Reward: 0.0
# Step: 273
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 2, 1]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-85', [2, 3]), Window [1, 1, 2]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-73', [1, 3]), Window [0, 0, 1]
# Conveyor: A-91 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | C-76 | --- | ---
# ----------------------------------------
#
# Step 274, Actions: [2 3 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  2.  1.  1.]
#  [ 7.  2.  3.  2.  2.  2.  2.  1.  2.  1.]
#  [11.  1.  3.  1.  2.  2.  2.  0.  1.  0.]]
# Reward: 0.0
# Step: 274
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [2, 1, 1]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-85', [2, 3]), Window [1, 2, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-73', [1, 3]), Window [0, 1, 0]
# Conveyor: --- | A-91 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | C-76 | ---
# ----------------------------------------
#
# Step 275, Actions: [0 1 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  1.  1.  0.]
#  [ 7.  2.  3.  2.  2.  2.  2.  2.  1.  1.]
#  [11.  1.  3.  1.  2.  2.  2.  1.  0.  1.]]
# Reward: 0.0
# Step: 275
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 1, 0]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-85', [2, 3]), Window [2, 1, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-73', [1, 3]), Window [1, 0, 1]
# Conveyor: --- | --- | A-91 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | C-76
# ----------------------------------------
#
# Step 276, Actions: [4 3 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  1.  0.  0.]
#  [ 7.  2.  3.  2.  2.  2.  2.  1.  1.  2.]
#  [11.  1.  3.  1.  2.  2.  2.  0.  1.  1.]]
# Reward: 0.0
# Step: 276
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-85', [2, 3]), Window [1, 1, 2]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-73', [1, 3]), Window [0, 1, 1]
# Conveyor: C-76 | --- | --- | A-91 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | ---
# ----------------------------------------
#
# Step 277, Actions: [4 4 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  0.  1.]
#  [ 7.  2.  3.  2.  2.  2.  2.  1.  2.  1.]
#  [11.  1.  3.  1.  2.  2.  2.  1.  1.  2.]]
# Reward: 0.0
# Step: 277
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [0, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-85', [2, 3]), Window [1, 2, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-73', [1, 3]), Window [1, 1, 2]
# Conveyor: --- | C-76 | --- | --- | A-91 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86
# ----------------------------------------
#
# Step 278, Actions: [0 3 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  1.  0.]
#  [ 7.  2.  3.  2.  2.  2.  2.  2.  1.  1.]
#  [11.  1.  3.  1.  2.  2.  2.  1.  2.  1.]]
# Reward: 0.0
# Step: 278
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [0, 1, 0]
# Agent 2 at pos 7: Status 2, Operation 2, Workbench ('B-85', [2, 3]), Window [2, 1, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-73', [1, 3]), Window [1, 2, 1]
# Conveyor: C-86 | --- | C-76 | --- | --- | A-91 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87
# ----------------------------------------
#
# Step 279, Actions: [0 3 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  1.  0.  1.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  1.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  2.  1.  1.]]
# Reward: 8.0
# Step: 279
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 0, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [2, 1, 1]
# Conveyor: C-87 | C-86 | --- | C-76 | --- | --- | A-91 | A-90 | B-89 | A-88 | C-78 | B-81
# ----------------------------------------
#
# Step 280, Actions: [4 1 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  0.  0.  0.  1.  1.]
#  [ 7.  2.  3.  0.  2.  0.  0.  1.  0.  0.]
#  [11.  1.  3.  0.  2.  0.  0.  1.  1.  2.]]
# Reward: -0.41666666666666674
# Step: 280
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [0, 1, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 1, 2]
# Conveyor: B-81 | C-87 | C-86 | --- | C-76 | --- | --- | A-91 | A-90 | B-89 | A-88 | C-78
# ----------------------------------------
#
# Step 281, Actions: [2 0 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  1.  2.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  0.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  1.  2.  1.]]
# Reward: -0.5833333333333334
# Step: 281
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [0, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 2, 1]
# Conveyor: C-78 | B-81 | C-87 | C-86 | --- | C-76 | --- | --- | --- | A-90 | B-89 | A-88
# ----------------------------------------
#
# Step 282, Actions: [3 4 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  2.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  1.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  2.  1.  0.]]
# Reward: -0.25
# Step: 282
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 2, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [0, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [2, 1, 0]
# Conveyor: A-88 | C-78 | B-81 | C-87 | C-86 | --- | C-76 | --- | --- | --- | A-90 | B-89
# ----------------------------------------
#
# Step 283, Actions: [0 4 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  1.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  0.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  1.  0.  0.]]
# Reward: -0.33333333333333337
# Step: 283
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [2, 1, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [1, 0, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Conveyor: B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | C-76 | --- | --- | --- | A-90
# ----------------------------------------
#
# Step 284, Actions: [2 1 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  1.  2.]
#  [ 7.  2.  3.  1.  2.  2.  0.  0.  1.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  0.]]
# Reward: -0.5
# Step: 284
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [0, 1, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | C-76 | --- | --- | ---
# ----------------------------------------
#
# Step 285, Actions: [2 1 1]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  2.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  1.  2.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  1.]]
# Reward: -0.25
# Step: 285
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 2, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [1, 1, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Conveyor: C-92 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | C-76 | --- | ---
# ----------------------------------------
#
# Step 286, Actions: [2 4 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  1.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  2.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  1.  0.]]
# Reward: -1.5
# Step: 286
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [2, 1, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [1, 2, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Conveyor: --- | C-92 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | C-76 | ---
# ----------------------------------------
#
# Step 287, Actions: [1 4 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  1.  0.]
#  [ 7.  2.  3.  1.  2.  2.  0.  2.  1.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  1.  0.  1.]]
# Reward: -1.0
# Step: 287
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 1, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [2, 1, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 1]
# Conveyor: --- | --- | C-92 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | C-76
# ----------------------------------------
#
# Step 288, Actions: [2 3 0]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  1.  0.  0.]
#  [ 7.  2.  3.  1.  2.  2.  2.  1.  1.  2.]
#  [11.  1.  3.  1.  2.  2.  2.  0.  1.  1.]]
# Reward: -0.5
# Step: 288
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 0, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [1, 1, 2]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-76', [1, 3]), Window [0, 1, 1]
# Conveyor: A-93 | --- | --- | C-92 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | ---
# ----------------------------------------
#
# Step 289, Actions: [0 3 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  0.  1.]
#  [ 7.  2.  3.  1.  2.  2.  2.  1.  2.  1.]
#  [11.  1.  3.  1.  2.  2.  2.  1.  1.  2.]]
# Reward: 0.0
# Step: 289
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [0, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [1, 2, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-76', [1, 3]), Window [1, 1, 2]
# Conveyor: --- | A-93 | --- | --- | C-92 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86
# ----------------------------------------
#
# Step 290, Actions: [3 1 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  1.  0.]
#  [ 7.  2.  3.  1.  2.  2.  2.  2.  1.  1.]
#  [11.  1.  3.  1.  2.  2.  2.  1.  2.  1.]]
# Reward: 0.0
# Step: 290
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [0, 1, 0]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [2, 1, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-76', [1, 3]), Window [1, 2, 1]
# Conveyor: C-86 | --- | A-93 | --- | --- | C-92 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87
# ----------------------------------------
#
# Step 291, Actions: [3 4 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  1.  0.  1.]
#  [ 7.  2.  3.  1.  2.  2.  2.  1.  1.  0.]
#  [11.  1.  3.  1.  2.  2.  2.  2.  1.  1.]]
# Reward: 0.0
# Step: 291
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [1, 0, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [1, 1, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-76', [1, 3]), Window [2, 1, 1]
# Conveyor: C-87 | C-86 | --- | A-93 | --- | --- | C-92 | A-90 | B-89 | A-88 | C-78 | B-81
# ----------------------------------------
#
# Step 292, Actions: [1 0 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  2.  0.  1.  1.]
#  [ 7.  2.  3.  1.  2.  2.  2.  1.  0.  0.]
#  [11.  1.  3.  1.  2.  2.  2.  1.  1.  2.]]
# Reward: 0.0
# Step: 292
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-69', [1, 2]), Window [0, 1, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-91', [1, 2]), Window [1, 0, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-76', [1, 3]), Window [1, 1, 2]
# Conveyor: B-81 | C-87 | C-86 | --- | A-93 | --- | --- | C-92 | A-90 | B-89 | A-88 | C-78
# ----------------------------------------
#
# Step 293, Actions: [1 4 1]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  1.  1.  2.]
#  [ 7.  2.  3.  0.  0.  0.  2.  0.  0.  1.]
#  [11.  1.  3.  1.  0.  0.  2.  1.  2.  1.]]
# Reward: 8.0
# Step: 293
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 1, 2]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-76', [1, 3]), Window [1, 2, 1]
# Conveyor: C-78 | B-81 | C-87 | C-86 | --- | A-93 | --- | --- | C-92 | A-90 | B-89 | A-88
# ----------------------------------------
#
# Step 294, Actions: [4 2 1]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  1.  2.  1.]
#  [ 7.  2.  3.  0.  0.  0.  2.  0.  1.  0.]
#  [11.  1.  3.  1.  0.  0.  2.  2.  1.  1.]]
# Reward: -0.33333333333333337
# Step: 294
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 2, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [0, 1, 0]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-76', [1, 3]), Window [2, 1, 1]
# Conveyor: A-88 | C-78 | B-81 | C-87 | C-86 | --- | A-93 | --- | --- | C-92 | A-90 | B-89
# ----------------------------------------
#
# Step 295, Actions: [2 0 2]
# Observations:
# [[ 3.  1.  2.  0.  0.  0.  2.  2.  1.  1.]
#  [ 7.  2.  3.  0.  0.  0.  2.  1.  0.  1.]
#  [11.  1.  3.  1.  0.  0.  2.  1.  1.  0.]]
# Reward: -1.3333333333333335
# Step: 295
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [2, 1, 1]
# Agent 2 at pos 7: Status 0, Operation 0, Workbench None, Window [1, 0, 1]
# Agent 3 at pos 11: Status 2, Operation 1, Workbench ('C-76', [1, 3]), Window [1, 1, 0]
# Conveyor: B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | A-93 | --- | --- | C-92 | A-90
# ----------------------------------------
#
# Step 296, Actions: [1 0 0]
# Observations:
# [[ 3.  1.  2.  0.  0.  2.  0.  1.  1.  2.]
#  [ 7.  2.  3.  1.  0.  2.  0.  0.  1.  1.]
#  [11.  1.  3.  0.  0.  2.  0.  1.  0.  0.]]
# Reward: 3.75
# Step: 296
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-93', [1, 2]), Window [0, 1, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [1, 0, 0]
# Conveyor: A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | --- | --- | --- | C-92
# ----------------------------------------
#
# Step 297, Actions: [1 1 3]
# Observations:
# [[ 3.  1.  2.  0.  0.  2.  0.  1.  2.  1.]
#  [ 7.  2.  3.  1.  0.  2.  0.  1.  1.  2.]
#  [11.  1.  3.  0.  0.  2.  0.  0.  0.  0.]]
# Reward: -0.9166666666666667
# Step: 297
# Agent 1 at pos 3: Status 0, Operation 0, Workbench None, Window [1, 2, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-93', [1, 2]), Window [1, 1, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: A-94 | A-90 | B-89 | A-88 | C-78 | B-81 | C-87 | C-86 | --- | --- | --- | ---
# ----------------------------------------
#
# Step 298, Actions: [0 4 4]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  2.  1.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  2.  1.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  0.]]
# Reward: -0.6666666666666667
# Step: 298
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-88', [1, 2]), Window [2, 1, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-93', [1, 2]), Window [1, 2, 1]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 0]
# Conveyor: B-95 | A-94 | A-90 | B-89 | --- | C-78 | B-81 | C-87 | C-86 | --- | --- | ---
# ----------------------------------------
#
# Step 299, Actions: [1 2 2]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  1.  2.]
#  [ 7.  2.  3.  1.  2.  2.  0.  2.  1.  0.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  0.  1.]]
# Reward: -0.33333333333333337
# Step: 299
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-88', [1, 2]), Window [1, 1, 2]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-93', [1, 2]), Window [2, 1, 0]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 0, 1]
# Conveyor: C-96 | B-95 | A-94 | A-90 | B-89 | --- | C-78 | B-81 | C-87 | C-86 | --- | ---
# ----------------------------------------
#
# Step 300, Actions: [4 4 3]
# Observations:
# [[ 3.  1.  2.  1.  2.  2.  0.  1.  2.  1.]
#  [ 7.  2.  3.  1.  2.  2.  0.  1.  0.  2.]
#  [11.  1.  3.  0.  2.  2.  0.  0.  1.  1.]]
# Reward: -1.0
# Step: 300
# Agent 1 at pos 3: Status 2, Operation 1, Workbench ('A-88', [1, 2]), Window [1, 2, 1]
# Agent 2 at pos 7: Status 2, Operation 1, Workbench ('A-93', [1, 2]), Window [1, 0, 2]
# Agent 3 at pos 11: Status 0, Operation 0, Workbench None, Window [0, 1, 1]
# Conveyor: --- | C-96 | B-95 | A-94 | A-90 | B-89 | --- | C-78 | B-81 | C-87 | C-86 | ---
# ----------------------------------------

# %%
# Define the operation type, which specifies the nature of work
class OperationType:
    def __init__(self, name, capable_machines):
        self.name = name                  # e.g., "Assembly", "Inspection"
        self.capable_machines = capable_machines  # list of machines/robots that can perform this op

    def __repr__(self):
        return f"OperationType({self.name})"

# A processing step is one stage in the product’s manufacturing process.
# It is linked with a specific operation type and has a base processing time.
class ProcessingStep:
    def __init__(self, step_id, operation_type, base_time):
        self.step_id = step_id            # Order of the step (e.g., 1, 2, 3,...)
        self.operation_type = operation_type
        self.base_time = base_time        # Base time required for this step

    def __repr__(self):
        return f"ProcessingStep(id={self.step_id}, op={self.operation_type.name}, time={self.base_time})"

# A product is defined in the product library.
# It provides the overall "recipe" for manufacturing an item, i.e., its ordered processing steps.
class Product:
    def __init__(self, product_id, name, processing_steps):
        self.product_id = product_id
        self.name = name
        self.processing_steps = processing_steps  # List of ProcessingStep objects in order

    def __repr__(self):
        return f"Product({self.name})"

# A job is an individual instance of a product that enters the production system.
class Job:
    def __init__(self, job_id, product):
        self.job_id = job_id
        self.product = product
        self.current_step_index = 0  # Start with the first processing step

    def get_next_processing_step(self):
        if self.current_step_index < len(self.product.processing_steps):
            return self.product.processing_steps[self.current_step_index]
        else:
            return None  # All steps completed

    def complete_current_step(self):
        # For simulation, we mark the current step as done and move to the next one.
        step = self.get_next_processing_step()
        if step:
            print(f"Job {self.job_id} completed step {step.step_id}: {step.operation_type.name}")
            self.current_step_index += 1
        else:
            print(f"Job {self.job_id} is fully completed.")

    def __repr__(self):
        return f"Job(id={self.job_id}, product={self.product.name}, step={self.current_step_index + 1})"

# --- Example Usage ---
if __name__ == '__main__':
    # Define some operation types
    op_assembly = OperationType("Assembly", capable_machines=["Robot1", "Robot2"])
    op_inspection = OperationType("Inspection", capable_machines=["Robot3"])
    op_packaging = OperationType("Packaging", capable_machines=["Robot4", "Robot5"])

    # Define processing steps for a product (each processing step is an instance of an operation)
    step1 = ProcessingStep(step_id=1, operation_type=op_assembly, base_time=30)
    step2 = ProcessingStep(step_id=2, operation_type=op_inspection, base_time=20)
    step3 = ProcessingStep(step_id=3, operation_type=op_packaging, base_time=15)

    # Define a product using an ordered list of processing steps
    product_A = Product(product_id=101, name="WidgetA", processing_steps=[step1, step2, step3])

    # Create a job (work order) as an instance of product_A
    job1 = Job(job_id=1, product=product_A)

    # Simulate the processing of job1 through its steps
    while (next_step := job1.get_next_processing_step()) is not None:
        print(f"Job {job1.job_id} is processing step {next_step.step_id}: {next_step.operation_type.name}")
        # Here you might assign a robot/machine based on next_step.operation_type.capable_machines,
        # schedule the task, and then mark the step as completed.
        job1.complete_current_step()

    print(f"Job {job1.job_id} completed all processing steps.")

# Output:
# Job 1 is processing step 1: Assembly
# Job 1 completed step 1: Assembly
# Job 1 is processing step 2: Inspection
# Job 1 completed step 2: Inspection
# Job 1 is processing step 3: Packaging
# Job 1 completed step 3: Packaging
# Job 1 is fully completed.
# Out:
# Job 1 is processing step 1: Assembly
# Job 1 completed step 1: Assembly
# Job 1 is processing step 2: Inspection
# Job 1 completed step 2: Inspection
# Job 1 is processing step 3: Packaging
# Job 1 completed step 3: Packaging
# Job 1 completed all processing steps.
